# %% [markdown]
# Install World Bank Python library: **wbgapi** provides a comprehensive interface to the World Bank's data and metadata APIs, more deatils available at - https://pypi.org/project/wbgapi/

# %%
pip install wbgapi
# Out:
# Requirement already satisfied: wbgapi in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (1.0.12)
# Requirement already satisfied: requests in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from wbgapi) (2.32.4)
# Requirement already satisfied: PyYAML in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from wbgapi) (6.0.2)
# Requirement already satisfied: tabulate in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from wbgapi) (0.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from requests->wbgapi) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from requests->wbgapi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from requests->wbgapi) (2025.6.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from requests->wbgapi) (3.10)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\prati\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# pip install pandas

# %% [markdown]
# **World Bank: Data Collection and Preprocessing**

# %%
## Import necessary libraries

import wbgapi as wb
import pandas as pd

# %% [markdown]
# Get all Sustainable Development Goals(SDG) Attributes using wbgapi
#
# SDG metrics are available under database id 46

# %%
# # 46	Sustainable Development Goals	SDG

all_items = []

wb.db = 46                            ## set the db id for following step
for item in wb.series.list():               ## get all indicators/items from the db
  item['db_name'] = 'Sustainable Development Goals'
  item['code'] = 'SDG'
  all_items.append(item)

# %%
## form WB SDG feture Dataframe

wb_sdg_features = pd.DataFrame( all_items).sort_values(by='value')
wb_sdg_features.head()
# Out:
#                    id                                              value  \
# 15     EG.CFT.ACCS.ZS  Access to clean fuels and technologies for coo...
# 19     EG.ELC.ACCS.ZS            Access to electricity (% of population)
# 17  EG.ELC.ACCS.RU.ZS  Access to electricity, rural (% of rural popul...
# 18  EG.ELC.ACCS.UR.ZS  Access to electricity, urban (% of urban popul...
# 69     FX.OWN.TOTL.ZS  Account ownership at a financial institution o...
#
#                           db_name code
# 15  Sustainable Development Goals  SDG
# 19  Sustainable Development Goals  SDG
# 17  Sustainable Development Goals  SDG
# 18  Sustainable Development Goals  SDG
# 69  Sustainable Development Goals  SDG

# %%
## List of metrics/features we are interested in

wb_feature_list = [
                'GDP per capita (current US$)',
                'Access to electricity (% of population)',
                'Urban population (% of total population)',
                'Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)',
                'Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)',
                'Poverty headcount ratio at national poverty lines (% of population)',
                'Rural poverty headcount ratio at national poverty lines (% of rural population)',
                'Urban poverty headcount ratio at national poverty lines (% of urban population)',
                'Literacy rate, youth total (% of people ages 15-24)',
                'Literacy rate, adult total (% of people ages 15 and above)',
                'Level of water stress: freshwater withdrawal as a proportion of available freshwater resources',
                'Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)',
                'Annual freshwater withdrawals, total (% of internal resources)',
                'Annual freshwater withdrawals, total (billion cubic meters)',
                'Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)',
                'Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)',
                'Annual freshwater withdrawals, industry (% of total freshwater withdrawal)',
                'People using at least basic sanitation services (% of population)',
                'People using at least basic sanitation services, rural (% of rural population)',
                'People using at least basic sanitation services, urban (% of urban population)',
                'Investment in water and sanitation with private participation (current US$)',
                'Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)',
                'Access to electricity (% of population)',
                'People using at least basic drinking water services (% of population)',
                'Gross capital formation (annual % growth)',
                'Adolescents out of school (% of lower secondary school age)',
                'CO2 emissions (metric tons per capita)',
                'PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)',
                'People practicing open defecation (% of population)',
                'Population living in slums (% of urban population)',
                'Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)'
                ]

# %%
## get WB indicator ids for the features
wb_sdg_ind = wb_sdg_features[wb_sdg_features['value'].str.strip().isin(wb_feature_list)]

# %%
## get last 10 years of data for the features

wb_sdg_ind_data = wb.data.DataFrame(list(wb_sdg_ind['id']), mrv=10).reset_index() # most recent 10 years
wb_sdg_ind_data = wb_sdg_ind_data.merge(wb_sdg_ind[['id','value']],how='left',left_on='series',right_on='id')
wb_sdg_ind_data.head()
# Out:
#   economy             series  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  \
# 0     ABW     EG.ELC.ACCS.ZS   100.0   100.0   100.0   100.0   100.0   100.0
# 1     ABW     EN.ATM.CO2E.PC     NaN     NaN     NaN     NaN     NaN     NaN
# 2     ABW  EN.ATM.PM25.MC.ZS     NaN     NaN     NaN     NaN     NaN     NaN
# 3     ABW  EN.POP.SLUM.UR.ZS     NaN     NaN     NaN     NaN     NaN     NaN
# 4     ABW  ER.GDP.FWTL.M3.KD     NaN     NaN     NaN     NaN     NaN     NaN
#
#    YR2017  YR2018  YR2019  YR2020                 id  \
# 0   100.0   100.0   100.0   100.0     EG.ELC.ACCS.ZS
# 1     NaN     NaN     NaN     NaN     EN.ATM.CO2E.PC
# 2     NaN     NaN     NaN     NaN  EN.ATM.PM25.MC.ZS
# 3     NaN     NaN     NaN     NaN  EN.POP.SLUM.UR.ZS
# 4     NaN     NaN     NaN     NaN  ER.GDP.FWTL.M3.KD
#
#                                                value
# 0            Access to electricity (% of population)
# 1             CO2 emissions (metric tons per capita)
# 2  PM2.5 air pollution, population exposed to lev...
# 3  Population living in slums (% of urban populat...
# 4  Water productivity, total (constant 2015 US$ G...

# %%
## get country names

economy_db = wb.economy.DataFrame().reset_index()
economy_db.head()
# Out:
#     id         name  aggregate  longitude  latitude region adminregion  \
# 0  ABW        Aruba      False   -70.0167  12.51670    LCN
# 1  AFG  Afghanistan      False    69.1761  34.52280    SAS         SAS
# 2  AGO       Angola      False    13.2420  -8.81155    SSF         SSA
# 3  ALB      Albania      False    19.8172  41.33170    ECS         ECA
# 4  AND      Andorra      False     1.5218  42.50750    ECS
#
#   lendingType incomeLevel       capitalCity
# 0         LNX         HIC        Oranjestad
# 1         IDX         LIC             Kabul
# 2         IBD         LMC            Luanda
# 3         IBD         UMC            Tirane
# 4         LNX         HIC  Andorra la Vella

# %%
## join country names

wb_sdg_ind_data = wb_sdg_ind_data[['economy', 'series', 'YR2011', 'YR2012', 'YR2013', 'YR2014', 'YR2015', 'YR2016', 'YR2017', 'YR2018', 'YR2019', 'YR2020', 'value']]
wb_sdg_ind_data = wb_sdg_ind_data.merge(economy_db[['id','name','region']], how='left',left_on='economy',right_on='id')
wb_sdg_ind_data.head()
# Out:
#   economy             series  YR2011  YR2012  YR2013  YR2014  YR2015  YR2016  \
# 0     ABW     EG.ELC.ACCS.ZS   100.0   100.0   100.0   100.0   100.0   100.0
# 1     ABW     EN.ATM.CO2E.PC     NaN     NaN     NaN     NaN     NaN     NaN
# 2     ABW  EN.ATM.PM25.MC.ZS     NaN     NaN     NaN     NaN     NaN     NaN
# 3     ABW  EN.POP.SLUM.UR.ZS     NaN     NaN     NaN     NaN     NaN     NaN
# 4     ABW  ER.GDP.FWTL.M3.KD     NaN     NaN     NaN     NaN     NaN     NaN
#
#    YR2017  YR2018  YR2019  YR2020  \
# 0   100.0   100.0   100.0   100.0
# 1     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN
#
#                                                value   id   name region
# 0            Access to electricity (% of population)  ABW  Aruba    LCN
# 1             CO2 emissions (metric tons per capita)  ABW  Aruba    LCN
# 2  PM2.5 air pollution, population exposed to lev...  ABW  Aruba    LCN
# 3  Population living in slums (% of urban populat...  ABW  Aruba    LCN
# 4  Water productivity, total (constant 2015 US$ G...  ABW  Aruba    LCN

# %%
## WB data in long format

wb_sdg_ind_data = wb_sdg_ind_data[['economy', 'series', 'YR2011', 'YR2012', 'YR2013', 'YR2014', 'YR2015', 'YR2016', 'YR2017', 'YR2018', 'YR2019', 'YR2020', 'value','name','region']]
wb_sdg_ind_data_long = wb_sdg_ind_data.melt(id_vars=['economy','series','value','name','region'],var_name='Year',value_name='Measure')
wb_sdg_ind_data_long['Year'] = wb_sdg_ind_data_long['Year'].str.lstrip("YR")
wb_sdg_ind_data_long.rename(columns={'Measure':'Value','name':'Country','value':'Metric'}, inplace=True)
wb_sdg_ind_data_long.head()
# Out:
#   economy             series  \
# 0     ABW     EG.ELC.ACCS.ZS
# 1     ABW     EN.ATM.CO2E.PC
# 2     ABW  EN.ATM.PM25.MC.ZS
# 3     ABW  EN.POP.SLUM.UR.ZS
# 4     ABW  ER.GDP.FWTL.M3.KD
#
#                                               Metric Country region  Year  \
# 0            Access to electricity (% of population)   Aruba    LCN  2011
# 1             CO2 emissions (metric tons per capita)   Aruba    LCN  2011
# 2  PM2.5 air pollution, population exposed to lev...   Aruba    LCN  2011
# 3  Population living in slums (% of urban populat...   Aruba    LCN  2011
# 4  Water productivity, total (constant 2015 US$ G...   Aruba    LCN  2011
#
#    Value
# 0  100.0
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN

# %% [markdown]
# **World Bank: Missing Data Analysis**
#
# We begin by calculating the number of missing values for each country and feature over the 10-year period. If a feature shows 10 missing values for a country, it indicates that the feature has no recorded data for that country across all 10 years.

# %%
## each country will have 10 records for each metric/indicator
## missing feature values for countries
misssing_values = wb_sdg_ind_data_long.groupby(['Country','Metric'])['Value'].apply(lambda x: x.isna().sum()).reset_index()
misssing_values.rename(columns={'Value':'Missing'}, inplace=True)
misssing_values
# Out:
#           Country                                             Metric  Missing
# 0     Afghanistan            Access to electricity (% of population)        0
# 1     Afghanistan  Adolescents out of school (% of lower secondar...       10
# 2     Afghanistan  Annual freshwater withdrawals, agriculture (% ...        8
# 3     Afghanistan  Annual freshwater withdrawals, domestic (% of ...        8
# 4     Afghanistan  Annual freshwater withdrawals, industry (% of ...        8
# ...           ...                                                ...      ...
# 7564     Zimbabwe  Poverty headcount ratio at national poverty li...        7
# 7565     Zimbabwe  Rural poverty headcount ratio at national pove...       10
# 7566     Zimbabwe           Urban population (% of total population)        0
# 7567     Zimbabwe  Urban poverty headcount ratio at national pove...       10
# 7568     Zimbabwe  Water productivity, total (constant 2015 US$ G...        8
#
# [7569 rows x 3 columns]

# %%
## There are 261 countries in total
## count of countries missing all values for a metric
misssing_values[misssing_values['Missing']==10]['Metric'].value_counts()
# Out:
# Metric
# Rural poverty headcount ratio at national poverty lines (% of rural population)                              261
# Urban poverty headcount ratio at national poverty lines (% of urban population)                              261
# Investment in water and sanitation with private participation (current US$)                                  229
# Educational attainment, at least completed lower secondary, population 25+, total (%) (cumulative)           127
# Educational attainment, at least completed upper secondary, population 25+, total (%) (cumulative)           126
# Poverty headcount ratio at national poverty lines (% of population)                                          117
# Population living in slums (% of urban population)                                                           106
# Level of water stress: freshwater withdrawal as a proportion of available freshwater resources                83
# Literacy rate, youth total (% of people ages 15-24)                                                           76
# Literacy rate, adult total (% of people ages 15 and above)                                                    75
# Gross capital formation (annual % growth)                                                                     58
# People using at least basic sanitation services, rural (% of rural population)                                51
# Adolescents out of school (% of lower secondary school age)                                                   47
# Annual freshwater withdrawals, total (% of internal resources)                                                42
# People using at least basic sanitation services, urban (% of urban population)                                41
# Water productivity, total (constant 2015 US$ GDP per cubic meter of total freshwater withdrawal)              41
# Annual freshwater withdrawals, industry (% of total freshwater withdrawal)                                    39
# Annual freshwater withdrawals, domestic (% of total freshwater withdrawal)                                    38
# Annual freshwater withdrawals, agriculture (% of total freshwater withdrawal)                                 38
# Annual freshwater withdrawals, total (billion cubic meters)                                                   37
# Mortality rate attributed to unsafe water, unsafe sanitation and lack of hygiene (per 100,000 population)     34
# CO2 emissions (metric tons per capita)                                                                        26
# PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total)                  23
# GDP per capita (current US$)                                                                                   4
# People using at least basic drinking water services (% of population)                                          2
# People using at least basic sanitation services (% of population)                                              2
# People practicing open defecation (% of population)                                                            2
# Urban population (% of total population)                                                                       2
# Access to electricity (% of population)                                                                        1
# Name: count, dtype: int64

# %% [markdown]
# **World Bank: Feature Selection**
#
# Next, we identify all countries that have data available for all 10 years for each feature. We then retain only those features that have complete data for more than 100 countries. This **availability-based feature selection** ensures we maximize country coverage in the analysis while maintaining data consistency.

# %%
## finding countries that have values for all 10 years for a feature
all_available = misssing_values[misssing_values['Missing']==0]
feat_country = all_available.groupby('Metric')['Country'].agg(['nunique', list]).reset_index()
feat_country
# Out:
#                                                Metric  nunique  \
# 0             Access to electricity (% of population)      259
# 1   Adolescents out of school (% of lower secondar...       62
# 2   Educational attainment, at least completed low...        4
# 3   Educational attainment, at least completed upp...        4
# 4                        GDP per capita (current US$)      245
# 5           Gross capital formation (annual % growth)      177
# 6   Investment in water and sanitation with privat...        5
# 7   Literacy rate, adult total (% of people ages 1...       39
# 8   Literacy rate, youth total (% of people ages 1...       39
# 9   People practicing open defecation (% of popula...      229
# 10  People using at least basic drinking water ser...      241
# 11  People using at least basic sanitation service...      232
# 12  People using at least basic sanitation service...      201
# 13  People using at least basic sanitation service...      213
# 14  Poverty headcount ratio at national poverty li...       11
# 15           Urban population (% of total population)      259
#
#                                                  list
# 0   [Afghanistan, Albania, Algeria, Andorra, Angol...
# 1   [Arab World, Azerbaijan, Belarus, Belize, Brun...
# 2        [Australia, Bangladesh, Portugal, Singapore]
# 3        [Australia, Bangladesh, Portugal, Singapore]
# 4   [Afghanistan, Albania, Algeria, American Samoa...
# 5   [Algeria, Angola, Arab World, Argentina, Armen...
# 6   [Brazil, China, East Asia & Pacific (IDA & IBR...
# 7   [Arab World, Bangladesh, Early-demographic div...
# 8   [Arab World, Bangladesh, Early-demographic div...
# 9   [Afghanistan, Albania, Algeria, American Samoa...
# 10  [Afghanistan, Albania, Algeria, American Samoa...
# 11  [Afghanistan, Albania, Algeria, American Samoa...
# 12  [Afghanistan, Albania, Algeria, Andorra, Angol...
# 13  [Afghanistan, Albania, Algeria, Andorra, Angol...
# 14  [Belarus, China, Costa Rica, Ecuador, Georgia,...
# 15  [Afghanistan, Albania, Algeria, American Samoa...

# %%
## defining scope where more than 100 countries have values
scope = feat_country[feat_country['nunique']>100]

from functools import reduce

intersection_result = reduce(set.intersection, scope['list'].map(set))
len(intersection_result),intersection_result
# Out:
# (158,
#  {'Algeria',
#   'Angola',
#   'Arab World',
#   'Armenia',
#   'Austria',
#   'Bangladesh',
#   'Belarus',
#   'Belgium',
#   'Belize',
#   'Benin',
#   'Bhutan',
#   'Bolivia',
#   'Botswana',
#   'Brazil',
#   'Bulgaria',
#   'Burundi',
#   'Cabo Verde',
#   'Cambodia',
#   'Cameroon',
#   'Canada',
#   'Central African Republic',
#   'Central Europe and the Baltics',
#   'Chad',
#   'Chile',
#   'China',
#   'Colombia',
#   'Congo, Dem. Rep.',
#   'Costa Rica',
#   "Cote d'Ivoire",
#   'Cuba',
#   'Cyprus',
#   'Czech Republic',
#   'Denmark',
#   'Dominican Republic',
#   'Early-demographic dividend',
#   'East Asia & Pacific',
#   'East Asia & Pacific (IDA & IBRD)',
#   'East Asia & Pacific (excluding high income)',
#   'Ecuador',
#   'Egypt, Arab Rep.',
#   'El Salvador',
#   'Estonia',
#   'Eswatini',
#   'Euro area',
#   'Europe & Central Asia',
#   'European Union',
#   'Finland',
#   'France',
#   'Gabon',
#   'Gambia, The',
#   'Georgia',
#   'Germany',
#   'Ghana',
#   'Greece',
#   'Greenland',
#   'Guatemala',
#   'Guinea',
#   'Guinea-Bissau',
#   'Haiti',
#   'Heavily indebted poor countries (HIPC)',
#   'High income',
#   'Honduras',
#   'Hungary',
#   'IBRD only',
#   'IDA & IBRD total',
#   'IDA blend',
#   'IDA only',
#   'IDA total',
#   'Iceland',
#   'India',
#   'Indonesia',
#   'Iraq',
#   'Ireland',
#   'Israel',
#   'Italy',
#   'Jamaica',
#   'Jordan',
#   'Kazakhstan',
#   'Kenya',
#   'Kyrgyz Republic',
#   'Late-demographic dividend',
#   'Latin America & Caribbean',
#   'Latin America & Caribbean (IDA & IBRD)',
#   'Latin America & Caribbean (excluding high income)',
#   'Latvia',
#   'Least developed countries: UN classification',
#   'Lesotho',
#   'Lithuania',
#   'Low & middle income',
#   'Low income',
#   'Lower middle income',
#   'Luxembourg',
#   'Madagascar',
#   'Mali',
#   'Malta',
#   'Marshall Islands',
#   'Mauritania',
#   'Mexico',
#   'Middle East & North Africa',
#   'Middle income',
#   'Moldova',
#   'Mongolia',
#   'Montenegro',
#   'Morocco',
#   'Mozambique',
#   'Namibia',
#   'Nepal',
#   'Netherlands',
#   'New Zealand',
#   'Nicaragua',
#   'Niger',
#   'Nigeria',
#   'North America',
#   'North Macedonia',
#   'Norway',
#   'OECD members',
#   'Oman',
#   'Pakistan',
#   'Panama',
#   'Paraguay',
#   'Peru',
#   'Philippines',
#   'Poland',
#   'Portugal',
#   'Post-demographic dividend',
#   'Pre-demographic dividend',
#   'Romania',
#   'Russian Federation',
#   'Rwanda',
#   'Senegal',
#   'Serbia',
#   'Sierra Leone',
#   'Slovak Republic',
#   'Solomon Islands',
#   'South Africa',
#   'South Asia',
#   'South Asia (IDA & IBRD)',
#   'Spain',
#   'Sri Lanka',
#   'Sub-Saharan Africa',
#   'Sub-Saharan Africa (IDA & IBRD)',
#   'Sub-Saharan Africa (excluding high income)',
#   'Sudan',
#   'Sweden',
#   'Switzerland',
#   'Tanzania',
#   'Timor-Leste',
#   'Togo',
#   'Tunisia',
#   'Uganda',
#   'Ukraine',
#   'United Kingdom',
#   'United States',
#   'Upper middle income',
#   'Uruguay',
#   'Vanuatu',
#   'West Bank and Gaza',
#   'World'})

# %%
## with availability-based feature selection technique, we end up with 9 features from world bank dataset
wb_final_features = list(feat_country[feat_country['nunique']>100]['Metric'].unique())
len(wb_final_features),wb_final_features
# Out:
# (9,
#  ['Access to electricity (% of population)',
#   'GDP per capita (current US$)',
#   'Gross capital formation (annual % growth)',
#   'People practicing open defecation (% of population)',
#   'People using at least basic drinking water services (% of population)',
#   'People using at least basic sanitation services (% of population)',
#   'People using at least basic sanitation services, rural (% of rural population)',
#   'People using at least basic sanitation services, urban (% of urban population)',
#   'Urban population (% of total population)'])

# %%
## we do still have missing values that we will treat later along with unsdg dataset

wb_final_df = wb_sdg_ind_data_long[(wb_sdg_ind_data_long['Metric'].isin(wb_final_features))]
wb_final_df.isna().sum()
# Out:
# economy       0
# series        0
# Metric        0
# Country       0
# region        0
# Year          0
# Value      2035
# dtype: int64

# %% [markdown]
# **UNSDG: Data Collection and Preprocessing**

# %% [markdown]
# The UNSDG data was downloaded in CSV format from the official UNSDG website and stored on Google Drive. To access the files in the Colab environment, we first mounted the Google Drive and then read the data from it.

# %%
pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
#      -------------------------------------- 250.9/250.9 KB 1.1 MB/s eta 0:00:00
# Collecting et-xmlfile
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-2.0.0 openpyxl-3.1.5
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\prati\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
## mount drive first
# from google.colab import drive
# drive.mount('/content/drive')

unsdg_df = pd.DataFrame()

## Read files one by one and append to a singal dataframe

for file_name in ['Goal6.xlsx','Goal9.xlsx','Goal11.xlsx','Goal13.xlsx']:
  # file_path = f'/content/drive/MyDrive/MII_UNSDG_DB/{file_name}'
  file_path = f'../data/{file_name}'
  file_data = pd.read_excel(file_path, sheet_name='data')
  df = file_data[['SeriesCode','SeriesDescription','GeoAreaName',	'TimePeriod','Value','Location','Activity']]
  unsdg_df = pd.concat([unsdg_df,df])

# %% [markdown]
# The UN SDG dataset contains data by location. We filter for *ALLAREA* to select only national-level data. For indicators with breakdowns by activity type, select *TOTAL* to capture overall performance.

# %%
unsdg_df.groupby('SeriesDescription')['Location'].agg('nunique')
# Out:
# SeriesDescription
# Carbon dioxide emissions from fuel combustion (millions of tonnes)                                                                                           0
# Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)    0
# Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)                                                    0
# Municipal Solid Waste collection coverage, by cities (%)                                                                                                     0
# Proportion of population covered by at least a 2G mobile network (%)                                                                                         0
# Proportion of population covered by at least a 3G mobile network (%)                                                                                         0
# Proportion of population covered by at least a 4G mobile network (%)                                                                                         0
# Proportion of population covered by at least a 5G mobile network (%)                                                                                         0
# Proportion of population using safely managed drinking water services, by urban/rural (%)                                                                    3
# Proportion of the rural population who live within 2 km of an all-season road                                                                                1
# Proportion of urban population living in inadequate housing (%)                                                                                              4
# Proportion of urban population living in slums (%)                                                                                                           1
# Research and development expenditure as a proportion of GDP (%)                                                                                              0
# Total greenhouse gas emissions without LULUCF for Annex I Parties (Mt CO₂ equivalent)                                                                        0
# Total greenhouse gas emissions without LULUCF for non-Annex I Parties (Mt CO₂ equivalent)                                                                    0
# Name: Location, dtype: int64

# %%
unsdg_df.groupby('SeriesDescription')['Activity'].agg('nunique')
# Out:
# SeriesDescription
# Carbon dioxide emissions from fuel combustion (millions of tonnes)                                                                                           2
# Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)    1
# Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)                                                    0
# Municipal Solid Waste collection coverage, by cities (%)                                                                                                     0
# Proportion of population covered by at least a 2G mobile network (%)                                                                                         0
# Proportion of population covered by at least a 3G mobile network (%)                                                                                         0
# Proportion of population covered by at least a 4G mobile network (%)                                                                                         0
# Proportion of population covered by at least a 5G mobile network (%)                                                                                         0
# Proportion of population using safely managed drinking water services, by urban/rural (%)                                                                    0
# Proportion of the rural population who live within 2 km of an all-season road                                                                                0
# Proportion of urban population living in inadequate housing (%)                                                                                              0
# Proportion of urban population living in slums (%)                                                                                                           0
# Research and development expenditure as a proportion of GDP (%)                                                                                              0
# Total greenhouse gas emissions without LULUCF for Annex I Parties (Mt CO₂ equivalent)                                                                        0
# Total greenhouse gas emissions without LULUCF for non-Annex I Parties (Mt CO₂ equivalent)                                                                    0
# Name: Activity, dtype: int64

# %%
unsdg_df['Location'].unique()
# Out:
# array(['ALLAREA', 'RURAL', 'URBAN', nan, 'CITY', 'TSUB'], dtype=object)

# %%
unsdg_df['Activity'].unique()
# Out:
# array([nan, 'TOTAL', 'ISIC4_C10T32X19', 'ISIC4_C'], dtype=object)

# %%
unsdg_df['SeriesDescription'].unique()
# Out:
# array(['Proportion of population using safely managed drinking water services, by urban/rural (%)',
#        'Proportion of the rural population who live within 2\xa0km of an all-season road',
#        'Carbon dioxide emissions from fuel combustion (millions of tonnes)',
#        'Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)',
#        'Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)',
#        'Research and development expenditure as a proportion of GDP (%)',
#        'Proportion of population covered by at least a 2G mobile network (%)',
#        'Proportion of population covered by at least a 3G mobile network (%)',
#        'Proportion of population covered by at least a 4G mobile network (%)',
#        'Proportion of population covered by at least a 5G mobile network (%)',
#        'Proportion of urban population living in inadequate housing (%)',
#        'Proportion of urban population living in slums (%)',
#        'Municipal Solid Waste collection coverage, by cities (%)',
#        'Total greenhouse gas emissions without LULUCF for Annex I Parties (Mt CO₂ equivalent)',
#        'Total greenhouse gas emissions without LULUCF for non-Annex I Parties (Mt CO₂ equivalent)'],
#       dtype=object)

# %%
# unsdg_df.columns

# %%
## Functions to give preference to national-level data

def filter_allarea_preference(group):
    locations = group['Location'].dropna().unique()
    if len(locations) > 1 and 'ALLAREA' in locations:
        return group[group['Location'] == 'ALLAREA']
    return group

def filter_activity_preference(group):
    locations = group['Activity'].dropna().unique()
    if len(locations) > 1 and 'TOTAL' in locations:
        return group[group['Activity'] == 'TOTAL']
    return group

unsdg_df_filtered = unsdg_df.groupby(['SeriesDescription','GeoAreaName','TimePeriod'], group_keys=False).apply(filter_allarea_preference)
unsdg_df_filtered = unsdg_df_filtered.groupby(['SeriesDescription','GeoAreaName','TimePeriod'], group_keys=False).apply(filter_activity_preference)
# Out:
# C:\Users\prati\AppData\Local\Temp\ipykernel_28472\2104098531.py:15: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unsdg_df_filtered = unsdg_df.groupby(['SeriesDescription','GeoAreaName','TimePeriod'], group_keys=False).apply(filter_allarea_preference)
# C:\Users\prati\AppData\Local\Temp\ipykernel_28472\2104098531.py:16: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   unsdg_df_filtered = unsdg_df_filtered.groupby(['SeriesDescription','GeoAreaName','TimePeriod'], group_keys=False).apply(filter_activity_preference)

# %%
# unsdg_df.shape, unsdg_df_filtered.shape

# %%
## validation to ensure we have at max 1 activity data
unsdg_df_filtered.groupby(['SeriesDescription'])['Activity'].agg('nunique')
# Out:
# SeriesDescription
# Carbon dioxide emissions from fuel combustion (millions of tonnes)                                                                                           1
# Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)    1
# Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)                                                    0
# Municipal Solid Waste collection coverage, by cities (%)                                                                                                     0
# Proportion of population covered by at least a 2G mobile network (%)                                                                                         0
# Proportion of population covered by at least a 3G mobile network (%)                                                                                         0
# Proportion of population covered by at least a 4G mobile network (%)                                                                                         0
# Proportion of population covered by at least a 5G mobile network (%)                                                                                         0
# Proportion of population using safely managed drinking water services, by urban/rural (%)                                                                    0
# Proportion of the rural population who live within 2 km of an all-season road                                                                                0
# Proportion of urban population living in inadequate housing (%)                                                                                              0
# Proportion of urban population living in slums (%)                                                                                                           0
# Research and development expenditure as a proportion of GDP (%)                                                                                              0
# Total greenhouse gas emissions without LULUCF for Annex I Parties (Mt CO₂ equivalent)                                                                        0
# Total greenhouse gas emissions without LULUCF for non-Annex I Parties (Mt CO₂ equivalent)                                                                    0
# Name: Activity, dtype: int64

# %%
# unsdg_df_filtered.groupby(['SeriesDescription','GeoAreaName','TimePeriod'])['Location'].agg('nunique').reset_index()

# %%
# unsdg_df_filtered[(unsdg_df_filtered['SeriesDescription']=='Proportion of urban population living in inadequate housing (%)') & (unsdg_df_filtered['GeoAreaName']=='Israel') & (unsdg_df_filtered['TimePeriod']==2018)]

# %%
## Changing 'United States of America' to 'United States' for uniformity in country names across world bank and

unsdg_df_filtered['GeoAreaName'] = unsdg_df_filtered['GeoAreaName'].replace('United States of America', 'United States')

# %%
# wb_final_df.head()

# %%
## Assigning regions to countries
country_region = wb_final_df[['Country','region']].drop_duplicates()

unsdg_df_filtered_region = unsdg_df_filtered.merge(country_region, how='left',left_on='GeoAreaName', right_on='Country')
unsdg_df_filtered_region.head()
# Out:
#    SeriesCode                                  SeriesDescription GeoAreaName  \
# 0  EN_ATM_CO2  Carbon dioxide emissions from fuel combustion ...     Albania
# 1  EN_ATM_CO2  Carbon dioxide emissions from fuel combustion ...     Albania
# 2  EN_ATM_CO2  Carbon dioxide emissions from fuel combustion ...     Albania
# 3  EN_ATM_CO2  Carbon dioxide emissions from fuel combustion ...     Albania
# 4  EN_ATM_CO2  Carbon dioxide emissions from fuel combustion ...     Albania
#
#    TimePeriod  Value Location Activity  Country region
# 0        2011   4.16      NaN    TOTAL  Albania    ECS
# 1        2012   3.50      NaN    TOTAL  Albania    ECS
# 2        2013   3.67      NaN    TOTAL  Albania    ECS
# 3        2014   4.14      NaN    TOTAL  Albania    ECS
# 4        2015   3.84      NaN    TOTAL  Albania    ECS

# %%
# unsdg_df_filtered.head()

# %% [markdown]
# **Final Dataset:** Concatenting World Bank and UN SDG datasets

# %%
## rename columns
wb_final_df_renamed = wb_final_df.rename(columns={
    'series': 'SeriesCode',
    'Metric': 'SeriesDescription',
    'Country': 'GeoAreaName',
    'Year': 'TimePeriod',
})
columns_to_keep = ['SeriesCode', 'SeriesDescription', 'GeoAreaName', 'TimePeriod', 'Value','region']
wb_selected = wb_final_df_renamed[columns_to_keep]

final_df = pd.concat([unsdg_df_filtered_region[columns_to_keep], wb_selected], ignore_index=True)
final_df
# Out:
#               SeriesCode                                  SeriesDescription  \
# 0             EN_ATM_CO2  Carbon dioxide emissions from fuel combustion ...
# 1             EN_ATM_CO2  Carbon dioxide emissions from fuel combustion ...
# 2             EN_ATM_CO2  Carbon dioxide emissions from fuel combustion ...
# 3             EN_ATM_CO2  Carbon dioxide emissions from fuel combustion ...
# 4             EN_ATM_CO2  Carbon dioxide emissions from fuel combustion ...
# ...                  ...                                                ...
# 44483  SH.STA.BASS.RU.ZS  People using at least basic sanitation service...
# 44484  SH.STA.BASS.UR.ZS  People using at least basic sanitation service...
# 44485     SH.STA.BASS.ZS  People using at least basic sanitation service...
# 44486     SH.STA.ODFC.ZS  People practicing open defecation (% of popula...
# 44487  SP.URB.TOTL.IN.ZS           Urban population (% of total population)
#
#       GeoAreaName TimePeriod      Value region
# 0         Albania       2011   4.160000    ECS
# 1         Albania       2012   3.500000    ECS
# 2         Albania       2013   3.670000    ECS
# 3         Albania       2014   4.140000    ECS
# 4         Albania       2015   3.840000    ECS
# ...           ...        ...        ...    ...
# 44483    Zimbabwe       2020  32.034173    SSF
# 44484    Zimbabwe       2020  41.829436    SSF
# 44485    Zimbabwe       2020  35.192363    SSF
# 44486    Zimbabwe       2020  23.498632    SSF
# 44487    Zimbabwe       2020  32.242000    SSF
#
# [44488 rows x 6 columns]

# %%
final_df.isna().sum()
# Out:
# SeriesCode              0
# SeriesDescription       0
# GeoAreaName             0
# TimePeriod              0
# Value                4296
# region               2865
# dtype: int64

# %% [markdown]
# **Reshaping and Formatting:** Transformed data from long format to wide format, where each row represents a country-year pair with all corresponding features as columns.

# %%
final_df['GeoAreaName'] = final_df['GeoAreaName'].str.strip()
final_df['SeriesCode'] = final_df['SeriesCode'].str.strip()
final_df['SeriesDescription'] = final_df['SeriesDescription'].str.strip()
final_df['Value'] = pd.to_numeric(final_df['Value'], errors='coerce')
final_df['TimePeriod'] = pd.to_numeric(final_df['TimePeriod'], errors='coerce')

final_df_flattened = final_df.pivot_table(columns='SeriesDescription',index=[ 'GeoAreaName', 'TimePeriod','region'], values='Value',aggfunc='mean').reset_index()
final_df_flattened.head()
# Out:
# SeriesDescription  GeoAreaName  TimePeriod region  \
# 0                  Afghanistan        2011    SAS
# 1                  Afghanistan        2012    SAS
# 2                  Afghanistan        2013    SAS
# 3                  Afghanistan        2014    SAS
# 4                  Afghanistan        2015    SAS
#
# SeriesDescription  Access to electricity (% of population)  \
# 0                                                43.222019
# 1                                                69.099998
# 2                                                68.290649
# 3                                                89.500000
# 4                                                71.500000
#
# SeriesDescription  Carbon dioxide emissions from fuel combustion (millions of tonnes)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  GDP per capita (current US$)  \
# 0                                    591.190030
# 1                                    638.845852
# 2                                    624.315455
# 3                                    614.223342
# 4                                    556.007221
#
# SeriesDescription  Gross capital formation (annual % growth)  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
#
# SeriesDescription  Municipal Solid Waste collection coverage, by cities (%)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  ...  \
# 0                  ...
# 1                  ...
# 2                  ...
# 3                  ...
# 4                  ...
#
# SeriesDescription  Proportion of population covered by at least a 4G mobile network (%)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                0.0
# 4                                                                0.0
#
# SeriesDescription  Proportion of population covered by at least a 5G mobile network (%)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  Proportion of population using safely managed drinking water services, by urban/rural (%)  \
# 0                                                           20.21288
# 1                                                           21.12400
# 2                                                           22.03447
# 3                                                           22.94430
# 4                                                           23.85359
#
# SeriesDescription  Proportion of the rural population who live within 2 km of an all-season road  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  Proportion of urban population living in inadequate housing (%)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  Proportion of urban population living in slums (%)  \
# 0                                                                NaN
# 1                                                           67.24795
# 2                                                                NaN
# 3                                                           69.68829
# 4                                                                NaN
#
# SeriesDescription  Research and development expenditure as a proportion of GDP (%)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  Total greenhouse gas emissions without LULUCF for Annex I Parties (Mt CO₂ equivalent)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  Total greenhouse gas emissions without LULUCF for non-Annex I Parties (Mt CO₂ equivalent)  \
# 0                                                           35.79963
# 1                                                           39.92459
# 2                                                           84.23133
# 3                                                           42.19574
# 4                                                           41.99515
#
# SeriesDescription  Urban population (% of total population)
# 0                                                    23.948
# 1                                                    24.160
# 2                                                    24.373
# 3                                                    24.587
# 4                                                    24.803
#
# [5 rows x 27 columns]

# %%
# final_df.groupby(['GeoAreaName'])['Value'].apply(lambda x: x.isna().sum()).reset_index()

# %%
final_df['SeriesDescription'].nunique(), final_df['TimePeriod'].nunique(),final_df['GeoAreaName'].nunique()
# Out:
# (24, 10, 317)

# %%
final_df.shape
# Out:
# (44488, 6)

# %%
# final_df_flattened.groupby('GeoAreaName')['TimePeriod'].count()

# %% [markdown]
# # Missing Data Analysis

# %% [markdown]
# We perform below operations to treat missing values -
#
# *   Drop features with **more than 60% missing values** or those considered redundant due to overlap with other indicators
# *   Drop country/region with missing values across all features
# *   For remaining missing values, applied **mean imputation at the regional level**, filling missing values with the average of all countries in the same region.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.2.6)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from seaborn) (2.3.0)
# Requirement already satisfied: pillow>=8 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.2.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.58.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\prati\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (22.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prati\appdata\roaming\python\python310\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\prati\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\prati\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (3.10.3)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.58.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prati\appdata\roaming\python\python310\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\prati\appdata\roaming\python\python310\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: pillow>=8 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (11.2.1)
# Requirement already satisfied: six>=1.5 in c:\users\prati\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 22.0.4; however, version 25.1.1 is available.
# You should consider upgrading via the 'c:\Users\prati\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# Set multi-index (Country-Year)
df_indexed = final_df_flattened.set_index(['GeoAreaName', 'TimePeriod'])

# Check missing values (True if NaN, False otherwise)
missing = df_indexed.isnull()

# Plot heatmap
plt.figure(figsize=(10, 6))
sns.heatmap(missing, cmap='Reds', cbar=True, yticklabels=True)
plt.title('Heatmap of Missing Values by Country and Year')
plt.xlabel('Features')
# plt.ylabel('GeoAreaName, TimePeriod')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\prati\AppData\Local\Temp\ipykernel_28472\3592558877.py:13: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
## find features with greater than 60% of total missing values across the dataframe
missing_pct = missing.sum()*100/final_df_flattened.shape[0]
missing_pct[missing_pct>60]
# Out:
# SeriesDescription
# Municipal Solid Waste collection coverage, by cities (%)                                     89.616858
# Proportion of population covered by at least a 5G mobile network (%)                         97.356322
# Proportion of the rural population who live within 2 km of an all-season road                99.157088
# Proportion of urban population living in inadequate housing (%)                              88.237548
# Proportion of urban population living in slums (%)                                           71.379310
# Research and development expenditure as a proportion of GDP (%)                              69.501916
# Total greenhouse gas emissions without LULUCF for Annex I Parties (Mt CO₂ equivalent)        85.823755
# Total greenhouse gas emissions without LULUCF for non-Annex I Parties (Mt CO₂ equivalent)    78.544061
# dtype: float64

# %%
# missing_pct

# %%
features_to_exclude = missing_pct[missing_pct>60].index.tolist()
len(features_to_exclude), features_to_exclude
# Out:
# (8,
#  ['Municipal Solid Waste collection coverage, by cities (%)',
#   'Proportion of population covered by at least a 5G mobile network (%)',
#   'Proportion of the rural population who live within 2\xa0km of an all-season road',
#   'Proportion of urban population living in inadequate housing (%)',
#   'Proportion of urban population living in slums (%)',
#   'Research and development expenditure as a proportion of GDP (%)',
#   'Total greenhouse gas emissions without LULUCF for Annex I Parties (Mt CO₂ equivalent)',
#   'Total greenhouse gas emissions without LULUCF for non-Annex I Parties (Mt CO₂ equivalent)'])

# %%
## features that are already covered by other features
drop_series = [
    'Proportion of population covered by at least a 3G mobile network (%)',
    'Proportion of population covered by at least a 4G mobile network (%)',
    'People using at least basic sanitation services, rural (% of rural population)',
    'People using at least basic sanitation services, urban (% of urban population)'
]
features_to_exclude.extend(drop_series)

# %%
final_cleaned_df = final_df_flattened.drop(columns=features_to_exclude)
final_cleaned_df.head()
# Out:
# SeriesDescription  GeoAreaName  TimePeriod region  \
# 0                  Afghanistan        2011    SAS
# 1                  Afghanistan        2012    SAS
# 2                  Afghanistan        2013    SAS
# 3                  Afghanistan        2014    SAS
# 4                  Afghanistan        2015    SAS
#
# SeriesDescription  Access to electricity (% of population)  \
# 0                                                43.222019
# 1                                                69.099998
# 2                                                68.290649
# 3                                                89.500000
# 4                                                71.500000
#
# SeriesDescription  Carbon dioxide emissions from fuel combustion (millions of tonnes)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  GDP per capita (current US$)  \
# 0                                    591.190030
# 1                                    638.845852
# 2                                    624.315455
# 3                                    614.223342
# 4                                    556.007221
#
# SeriesDescription  Gross capital formation (annual % growth)  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
#
# SeriesDescription  People practicing open defecation (% of population)  \
# 0                                                          17.669144
# 1                                                          16.860403
# 2                                                          16.053442
# 3                                                          15.248276
# 4                                                          14.444733
#
# SeriesDescription  People using at least basic drinking water services (% of population)  \
# 0                                                          50.827846
# 1                                                          53.403517
# 2                                                          56.014043
# 3                                                          58.659374
# 4                                                          61.339781
#
# SeriesDescription  People using at least basic sanitation services (% of population)  \
# 0                                                          36.425149
# 1                                                          37.960809
# 2                                                          39.506018
# 3                                                          41.060966
# 4                                                          42.626023
#
# SeriesDescription  Proportion of population covered by at least a 2G mobile network (%)  \
# 0                                                               85.0
# 1                                                               88.0
# 2                                                               88.6
# 3                                                               89.0
# 4                                                               89.2
#
# SeriesDescription  Proportion of population using safely managed drinking water services, by urban/rural (%)  \
# 0                                                           20.21288
# 1                                                           21.12400
# 2                                                           22.03447
# 3                                                           22.94430
# 4                                                           23.85359
#
# SeriesDescription  Urban population (% of total population)
# 0                                                    23.948
# 1                                                    24.160
# 2                                                    24.373
# 3                                                    24.587
# 4                                                    24.803

# %%
## find countries with all missing values

feat_country_all_missing ={}
for col in final_cleaned_df.columns:
  if col not in ['GeoAreaName',	'TimePeriod',	'region']:
    missing_col_count = final_cleaned_df.groupby('GeoAreaName')[col].apply(lambda x: x.isna().sum()).reset_index()
    all_missing_countries = missing_col_count[missing_col_count[col]==10]['GeoAreaName'].unique()
    for country in all_missing_countries:
      counrty_region = final_cleaned_df[final_cleaned_df['GeoAreaName']==country]['region'].unique().tolist()
      other_counrty_same_region = final_cleaned_df[~(final_cleaned_df['GeoAreaName'].isin(all_missing_countries)) & (final_cleaned_df['region'].isin(counrty_region))][['GeoAreaName','region']].drop_duplicates()
      if other_counrty_same_region.shape[0]==0:
        feat_country_all_missing[col] = [country]

# %%
feat_country_all_missing
# Out:
# {'Carbon dioxide emissions from fuel combustion (millions of tonnes)': ['World'],
#  'Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)': ['World'],
#  'Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)': ['World'],
#  'Proportion of population covered by at least a 2G mobile network (%)': ['World'],
#  'Proportion of population using safely managed drinking water services, by urban/rural (%)': ['World']}

# %%
# final_cleaned_df.groupby('region')['GeoAreaName'].agg(['nunique',set])

# %%
country_to_exclude = set()
for val in feat_country_all_missing.values():
  for i in val:
    country_to_exclude.add(i)
country_to_exclude
# Out:
# {'World'}

# %%
final_cleaned_df = final_cleaned_df[~final_cleaned_df['GeoAreaName'].isin(country_to_exclude)]
final_cleaned_df.head()
# Out:
# SeriesDescription  GeoAreaName  TimePeriod region  \
# 0                  Afghanistan        2011    SAS
# 1                  Afghanistan        2012    SAS
# 2                  Afghanistan        2013    SAS
# 3                  Afghanistan        2014    SAS
# 4                  Afghanistan        2015    SAS
#
# SeriesDescription  Access to electricity (% of population)  \
# 0                                                43.222019
# 1                                                69.099998
# 2                                                68.290649
# 3                                                89.500000
# 4                                                71.500000
#
# SeriesDescription  Carbon dioxide emissions from fuel combustion (millions of tonnes)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)  \
# 0                                                                NaN
# 1                                                                NaN
# 2                                                                NaN
# 3                                                                NaN
# 4                                                                NaN
#
# SeriesDescription  GDP per capita (current US$)  \
# 0                                    591.190030
# 1                                    638.845852
# 2                                    624.315455
# 3                                    614.223342
# 4                                    556.007221
#
# SeriesDescription  Gross capital formation (annual % growth)  \
# 0                                                        NaN
# 1                                                        NaN
# 2                                                        NaN
# 3                                                        NaN
# 4                                                        NaN
#
# SeriesDescription  People practicing open defecation (% of population)  \
# 0                                                          17.669144
# 1                                                          16.860403
# 2                                                          16.053442
# 3                                                          15.248276
# 4                                                          14.444733
#
# SeriesDescription  People using at least basic drinking water services (% of population)  \
# 0                                                          50.827846
# 1                                                          53.403517
# 2                                                          56.014043
# 3                                                          58.659374
# 4                                                          61.339781
#
# SeriesDescription  People using at least basic sanitation services (% of population)  \
# 0                                                          36.425149
# 1                                                          37.960809
# 2                                                          39.506018
# 3                                                          41.060966
# 4                                                          42.626023
#
# SeriesDescription  Proportion of population covered by at least a 2G mobile network (%)  \
# 0                                                               85.0
# 1                                                               88.0
# 2                                                               88.6
# 3                                                               89.0
# 4                                                               89.2
#
# SeriesDescription  Proportion of population using safely managed drinking water services, by urban/rural (%)  \
# 0                                                           20.21288
# 1                                                           21.12400
# 2                                                           22.03447
# 3                                                           22.94430
# 4                                                           23.85359
#
# SeriesDescription  Urban population (% of total population)
# 0                                                    23.948
# 1                                                    24.160
# 2                                                    24.373
# 3                                                    24.587
# 4                                                    24.803

# %%
all_cols = final_cleaned_df.columns
feature_cols = all_cols.drop(['GeoAreaName',	'TimePeriod',	'region'])

# %%
## correlation before imputing missing values
final_cleaned_df[feature_cols].corr()['Proportion of population using safely managed drinking water services, by urban/rural (%)']
# Out:
# SeriesDescription
# Access to electricity (% of population)                                                                                                                      0.711198
# Carbon dioxide emissions from fuel combustion (millions of tonnes)                                                                                           0.119034
# Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)   -0.139611
# Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)                                                    0.233376
# GDP per capita (current US$)                                                                                                                                 0.545522
# Gross capital formation (annual % growth)                                                                                                                   -0.087510
# People practicing open defecation (% of population)                                                                                                         -0.700449
# People using at least basic drinking water services (% of population)                                                                                        0.781609
# People using at least basic sanitation services (% of population)                                                                                            0.821731
# Proportion of population covered by at least a 2G mobile network (%)                                                                                         0.553927
# Proportion of population using safely managed drinking water services, by urban/rural (%)                                                                    1.000000
# Urban population (% of total population)                                                                                                                     0.662670
# Name: Proportion of population using safely managed drinking water services, by urban/rural (%), dtype: float64

# %%
# final_cleaned_df['region'].unique()

# %%
final_cleaned_df.isna().sum()
# Out:
# SeriesDescription
# GeoAreaName                                                                                                                                                     0
# TimePeriod                                                                                                                                                      0
# region                                                                                                                                                          0
# Access to electricity (% of population)                                                                                                                        13
# Carbon dioxide emissions from fuel combustion (millions of tonnes)                                                                                           1331
# Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)    1341
# Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)                                                    1341
# GDP per capita (current US$)                                                                                                                                   82
# Gross capital formation (annual % growth)                                                                                                                     674
# People practicing open defecation (% of population)                                                                                                           118
# People using at least basic drinking water services (% of population)                                                                                          68
# People using at least basic sanitation services (% of population)                                                                                              98
# Proportion of population covered by at least a 2G mobile network (%)                                                                                         1156
# Proportion of population using safely managed drinking water services, by urban/rural (%)                                                                    1313
# Urban population (% of total population)                                                                                                                       20
# dtype: int64

# %%
## countries with any missing values
final_cleaned_df[(final_cleaned_df.isna().any(axis=1)) & ~(final_cleaned_df['region']=='')][['GeoAreaName','region']].drop_duplicates()
# Out:
# SeriesDescription            GeoAreaName region
# 0                            Afghanistan    SAS
# 19                               Albania    ECS
# 20                               Algeria    MEA
# 30                        American Samoa    EAS
# 40                               Andorra    ECS
# ...                                  ...    ...
# 2550               Virgin Islands (U.S.)    LCN
# 2560                  West Bank and Gaza    MEA
# 2580                         Yemen, Rep.    MEA
# 2590                              Zambia    SSF
# 2608                            Zimbabwe    SSF
#
# [174 rows x 2 columns]

# %%
## Region level missing value imputation

for col in feature_cols:
    final_cleaned_df[col] = final_cleaned_df.groupby(['region', 'TimePeriod'])[col].transform(
        lambda x: x.fillna(x.mean())
    )

# %%
final_cleaned_df.isna().sum()
# Out:
# SeriesDescription
# GeoAreaName                                                                                                                                                    0
# TimePeriod                                                                                                                                                     0
# region                                                                                                                                                         0
# Access to electricity (% of population)                                                                                                                        0
# Carbon dioxide emissions from fuel combustion (millions of tonnes)                                                                                           430
# Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)    430
# Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)                                                    430
# GDP per capita (current US$)                                                                                                                                   0
# Gross capital formation (annual % growth)                                                                                                                      0
# People practicing open defecation (% of population)                                                                                                            0
# People using at least basic drinking water services (% of population)                                                                                          0
# People using at least basic sanitation services (% of population)                                                                                              0
# Proportion of population covered by at least a 2G mobile network (%)                                                                                         430
# Proportion of population using safely managed drinking water services, by urban/rural (%)                                                                    430
# Urban population (% of total population)                                                                                                                       0
# dtype: int64

# %%
## analysing countries with still missing values
final_cleaned_df[final_cleaned_df['Proportion of population covered by at least a 2G mobile network (%)'].isna()][['GeoAreaName','region']].drop_duplicates()
# Out:
# SeriesDescription                                        GeoAreaName region
# 70                                                        Arab World
# 370                                           Caribbean small states
# 400                                   Central Europe and the Baltics
# 600                                       Early-demographic dividend
# 610                                              East Asia & Pacific
# 620                                 East Asia & Pacific (IDA & IBRD)
# 630                      East Asia & Pacific (excluding high income)
# 720                                                        Euro area
# 730                                            Europe & Central Asia
# 740                               Europe & Central Asia (IDA & IBRD)
# 750                    Europe & Central Asia (excluding high income)
# 760                                                   European Union
# 970                           Heavily indebted poor countries (HIPC)
# 980                                                      High income
# 1020                                                       IBRD only
# 1030                                                IDA & IBRD total
# 1040                                                       IDA blend
# 1050                                                        IDA only
# 1060                                                       IDA total
# 1280                                       Late-demographic dividend
# 1290                                       Latin America & Caribbean
# 1300                          Latin America & Caribbean (IDA & IBRD)
# 1310               Latin America & Caribbean (excluding high income)
# 1330                    Least developed countries: UN classification
# 1400                                             Low & middle income
# 1410                                                      Low income
# 1420                                             Lower middle income
# 1560                                      Middle East & North Africa
# 1570                         Middle East & North Africa (IDA & IBRD)
# 1580               Middle East & North Africa (excluding high inc...
# 1590                                                   Middle income
# 1760                                                   North America
# 1800                                                    OECD members
# 1820                                              Other small states
# 1920                                       Post-demographic dividend
# 1930                                        Pre-demographic dividend
# 2110                                                    Small states
# 2150                                                      South Asia
# 2160                                         South Asia (IDA & IBRD)
# 2240                                              Sub-Saharan Africa
# 2250                                 Sub-Saharan Africa (IDA & IBRD)
# 2260                      Sub-Saharan Africa (excluding high income)
# 2490                                             Upper middle income

# %%
## as we can see above, these are not the countries but grouped regions, so dropping these from our dataset

final_cleaned_df = final_cleaned_df.dropna()
final_cleaned_df.head()
# Out:
# SeriesDescription  GeoAreaName  TimePeriod region  \
# 0                  Afghanistan        2011    SAS
# 1                  Afghanistan        2012    SAS
# 2                  Afghanistan        2013    SAS
# 3                  Afghanistan        2014    SAS
# 4                  Afghanistan        2015    SAS
#
# SeriesDescription  Access to electricity (% of population)  \
# 0                                                43.222019
# 1                                                69.099998
# 2                                                68.290649
# 3                                                89.500000
# 4                                                71.500000
#
# SeriesDescription  Carbon dioxide emissions from fuel combustion (millions of tonnes)  \
# 0                                                            372.258
# 1                                                            401.982
# 2                                                            412.778
# 3                                                            450.262
# 4                                                            460.030
#
# SeriesDescription  Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)  \
# 0                                                             0.9588
# 1                                                             1.0220
# 2                                                             0.9378
# 3                                                             1.0262
# 4                                                             1.0408
#
# SeriesDescription  Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)  \
# 0                                                             0.1186
# 1                                                             0.1212
# 2                                                             0.1152
# 3                                                             0.1198
# 4                                                             0.1176
#
# SeriesDescription  GDP per capita (current US$)  \
# 0                                    591.190030
# 1                                    638.845852
# 2                                    624.315455
# 3                                    614.223342
# 4                                    556.007221
#
# SeriesDescription  Gross capital formation (annual % growth)  \
# 0                                                   6.526510
# 1                                                   7.870495
# 2                                                  -5.403038
# 3                                                  12.263828
# 4                                                   9.642426
#
# SeriesDescription  People practicing open defecation (% of population)  \
# 0                                                          17.669144
# 1                                                          16.860403
# 2                                                          16.053442
# 3                                                          15.248276
# 4                                                          14.444733
#
# SeriesDescription  People using at least basic drinking water services (% of population)  \
# 0                                                          50.827846
# 1                                                          53.403517
# 2                                                          56.014043
# 3                                                          58.659374
# 4                                                          61.339781
#
# SeriesDescription  People using at least basic sanitation services (% of population)  \
# 0                                                          36.425149
# 1                                                          37.960809
# 2                                                          39.506018
# 3                                                          41.060966
# 4                                                          42.626023
#
# SeriesDescription  Proportion of population covered by at least a 2G mobile network (%)  \
# 0                                                               85.0
# 1                                                               88.0
# 2                                                               88.6
# 3                                                               89.0
# 4                                                               89.2
#
# SeriesDescription  Proportion of population using safely managed drinking water services, by urban/rural (%)  \
# 0                                                           20.21288
# 1                                                           21.12400
# 2                                                           22.03447
# 3                                                           22.94430
# 4                                                           23.85359
#
# SeriesDescription  Urban population (% of total population)
# 0                                                    23.948
# 1                                                    24.160
# 2                                                    24.373
# 3                                                    24.587
# 4                                                    24.803

# %%
final_cleaned_df[feature_cols].corr()['Proportion of population using safely managed drinking water services, by urban/rural (%)']
# Out:
# SeriesDescription
# Access to electricity (% of population)                                                                                                                      0.697354
# Carbon dioxide emissions from fuel combustion (millions of tonnes)                                                                                           0.128702
# Carbon dioxide emissions from manufacturing industries per unit of manufacturing value added (kilogrammes of CO2 per constant 2015 United States dollars)    0.048093
# Carbon dioxide emissions per unit of GDP PPP (kilogrammes of CO2 per constant 2021 United States dollars)                                                    0.250996
# GDP per capita (current US$)                                                                                                                                 0.530437
# Gross capital formation (annual % growth)                                                                                                                   -0.070324
# People practicing open defecation (% of population)                                                                                                         -0.614369
# People using at least basic drinking water services (% of population)                                                                                        0.725358
# People using at least basic sanitation services (% of population)                                                                                            0.784221
# Proportion of population covered by at least a 2G mobile network (%)                                                                                         0.514094
# Proportion of population using safely managed drinking water services, by urban/rural (%)                                                                    1.000000
# Urban population (% of total population)                                                                                                                     0.561007
# Name: Proportion of population using safely managed drinking water services, by urban/rural (%), dtype: float64

# %%
final_cleaned_df.to_csv('../data/final_cleaned_df.csv',index=False)

# %%
final_cleaned_df.shape
# Out:
# (2170, 15)

# %%
final_cleaned_df['region'].unique()
# Out:
# array(['SAS', 'ECS', 'MEA', 'EAS', 'SSF', 'LCN', 'NAC'], dtype=object)

# %%
# final_cleaned_df.groupby('region')['GeoAreaName'].agg(['nunique',set])
# final_cleaned_df[final_cleaned_df['GeoAreaName']=='Tuvalu']

# %%
# final_df_flattened[final_df_flattened['GeoAreaName']=='Tuvalu'][final_cleaned_df.columns.tolist()]

# %% [markdown]
# Analysing countries from same region

# %%
first10_countries = final_cleaned_df[final_cleaned_df['region']=='SAS']['GeoAreaName'].unique()[:10]
first10_countries
# Out:
# array(['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives',
#        'Nepal', 'Pakistan', 'Sri Lanka'], dtype=object)

# %%
df_melted = final_cleaned_df[final_cleaned_df['GeoAreaName'].isin(first10_countries)].melt(id_vars=['GeoAreaName', 'TimePeriod'],
                    value_vars=feature_cols,
                    var_name='Feature',
                    value_name='Value')

g = sns.FacetGrid(df_melted, col="GeoAreaName", row="Feature", margin_titles=True,
                  sharey=False, sharex=True, height=2.5, aspect=2)


g.map(sns.lineplot, "TimePeriod", "Value", marker="o")

g.set_axis_labels("Year", "Value")
g.set_titles(col_template="{col_name}", row_template="{row_name}")
plt.tight_layout()
plt.show()
# Out:
# c:\Users\prati\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# c:\Users\prati\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\prati\AppData\Local\Temp\ipykernel_28472\1394228344.py:14: UserWarning: Tight layout not applied. tight_layout cannot make Axes height small enough to accommodate all Axes decorations.
#   plt.tight_layout()
